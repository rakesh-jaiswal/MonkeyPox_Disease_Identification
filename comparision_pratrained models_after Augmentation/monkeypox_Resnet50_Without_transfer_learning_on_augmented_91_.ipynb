# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import random
from tensorflow.keras import layers, Model
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install split-folders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import splitfolders

# Split with a ratio.
# To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.
splitfolders.ratio("/content/drive/MyDrive/parent_TRAIN_VAL_AUGMENTED/augmeneted_latest_4_class", output="train_val-augmented",
    seed=1337, ratio=(.8, .2), group_prefix=None, move=False) # default values
# Out:
# Copying files: 3101 files [00:47, 64.94 files/s]

# %%
train_dir = "/content/train_val-augmented/train"
val_dir = "/content/train_val-augmented/val"
test_dir = "/content/drive/MyDrive/parent_TRAIN_VAL_AUGMENTED/test"

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
                                                          # featurewise_center=True,
                                                          # featurewise_std_normalization=True,
                                                          # rotation_range=90,
                                                          # width_shift_range=0.2,
                                                          # height_shift_range=0.2,
                                                          # horizontal_flip=True,
                                                          # zoom_range=0.2,
                                                          )

# %%
train_gen = datagen.flow_from_directory(train_dir,
                                                 target_size = (224,224),
                                                 batch_size = 32,
                                        shuffle=True,
                                                 class_mode = 'categorical')
test_gen= datagen.flow_from_directory(test_dir,
                                            target_size = (224,224),
                                            batch_size = 32,
                                      shuffle=False,
                                            class_mode ='categorical')
val_gen = datagen.flow_from_directory(val_dir,
                                            target_size = (224,224),
                                            batch_size = 32,
                                      shuffle=True,
                                          class_mode = 'categorical')
# Out:
# Found 2479 images belonging to 4 classes.
# Found 79 images belonging to 4 classes.
# Found 622 images belonging to 4 classes.

# %%
# IMG_SIZE = (224, 224)

# train_data = tf.keras.preprocessing.image_dataset_from_directory(directory=train_dir,
#                                                                  image_size=IMG_SIZE,
#                                                                  label_mode="categorical",
#                                                                  shuffle=True,
#                                                                  batch_size=32)


# test_data = tf.keras.preprocessing.image_dataset_from_directory(directory=test_dir,
#                                                                  image_size=IMG_SIZE,
#                                                                  label_mode="categorical",
#                                                                  batch_size=32,
#                                                                 shuffle=False)

# val_data = tf.keras.preprocessing.image_dataset_from_directory(directory=val_dir,
#                                                                  image_size=IMG_SIZE,
#                                                                  label_mode="categorical",
#                                                                  batch_size=32,
#                                                                 shuffle=True)

# %%
# Visualizing data
import os 
def visualize_random_images(dataset_type="train", label_type="Monkeypox"):
    
    sample = 9
    
    plt.figure(figsize=(15, 8))
    type_dir = train_dir if dataset_type=="train" else test_dir
    base_dir = os.path.join(type_dir, label_type)
    images = random.sample(os.listdir(base_dir), 9)
    
    for i, image in enumerate(images):
        plt.subplot(3, 3, i+1)
        img = plt.imread(os.path.join(base_dir, image))
        plt.imshow(img)

# %%
visualize_random_images("train","monkeypox_TV_augmented")

# %%
def plot_loss_curves(history):
  """
  Returns separate loss curves for training and validation metrics.
  Args:
    history: TensorFlow model History object (see: https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/History)
  """ 
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  # Plot accuracy
  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

# %%
# base_model =tf.keras.applications.vgg16.VGG16(include_top=False)
# base_model.trainable = False

# for layer in base_model.layers[:-5]:
#   layer.trainable = False

# inputs = layers.Input(shape=(224, 224, 3), name="input_layer")
# base_layer = base_model(inputs)
# dropout_layer_1 = layers.Dropout(0.2)(base_layer)
# flat_layer = layers.Flatten()(dropout_layer_1)
# dense_1 = layers.Dense(512, activation="relu")(flat_layer)
# dropout_layer_2 = layers.Dropout(0.2)(dense_1)
# dense_2 = layers.Dense(512, activation="relu")(dropout_layer_2)
# outputs = layers.Dense(4, activation="sigmoid")(dense_2)
# model = Model(inputs, outputs)

# %%
base_model =tf.keras.applications.resnet50.ResNet50(include_top=False)
base_model.trainable = False

for layer in base_model.layers[:-5]:
  layer.trainable = False

inputs = layers.Input(shape=(224, 224, 3), name="input_layer")
base_layer = base_model(inputs)

flat_layer = layers.Flatten()(base_layer)

outputs = layers.Dense(4, activation="softmax")(flat_layer)
model = Model(inputs, outputs)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step
# 94781440/94765736 [==============================] - 0s 0us/step

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001),
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = model.fit(train_gen,
                       epochs=40,
                       validation_data=val_gen)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/40
# 78/78 [==============================] - 30s 155ms/step - loss: 3.5995 - accuracy: 0.7713 - val_loss: 1.3730 - val_accuracy: 0.8859
# Epoch 2/40
# 78/78 [==============================] - 10s 131ms/step - loss: 0.5238 - accuracy: 0.9520 - val_loss: 1.0264 - val_accuracy: 0.9132
# Epoch 3/40
# 78/78 [==============================] - 10s 131ms/step - loss: 0.1341 - accuracy: 0.9818 - val_loss: 1.5893 - val_accuracy: 0.9100
# Epoch 4/40
# 78/78 [==============================] - 10s 133ms/step - loss: 0.1088 - accuracy: 0.9839 - val_loss: 1.7065 - val_accuracy: 0.9003
# Epoch 5/40
# 78/78 [==============================] - 10s 132ms/step - loss: 0.2551 - accuracy: 0.9762 - val_loss: 2.3367 - val_accuracy: 0.8907
# Epoch 6/40
# 78/78 [==============================] - 10s 133ms/step - loss: 0.1150 - accuracy: 0.9863 - val_loss: 1.7511 - val_accuracy: 0.9084
# Epoch 7/40
# 78/78 [==============================] - 10s 133ms/step - loss: 0.0697 - accuracy: 0.9919 - val_loss: 1.9436 - val_accuracy: 0.9164
# Epoch 8/40
# 78/78 [==============================] - 10s 134ms/step - loss: 0.0962 - accuracy: 0.9891 - val_loss: 1.8263 - val_accuracy: 0.9084
# Epoch 9/40
# 78/78 [==============================] - 11s 134ms/step - loss: 0.1268 - accuracy: 0.9891 - val_loss: 2.8596 - val_accuracy: 0.8633
# Epoch 10/40
# 78/78 [==============================] - 11s 138ms/step - loss: 0.0696 - accuracy: 0.9899 - val_loss: 2.1196 - val_accuracy: 0.9116
# Epoch 11/40
# 78/78 [==============================] - 11s 136ms/step - loss: 0.0902 - accuracy: 0.9903 - val_loss: 2.4750 - val_accuracy: 0.8987
# Epoch 12/40
# 78/78 [==============================] - 11s 136ms/step - loss: 0.1030 - accuracy: 0.9907 - val_loss: 2.7854 - val_accuracy: 0.9068
# Epoch 13/40
# 78/78 [==============================] - 11s 136ms/step - loss: 0.1073 - accuracy: 0.9895 - val_loss: 3.2701 - val_accuracy: 0.9051
# Epoch 14/40
# Epoch 33/40
# 78/78 [==============================] - 11s 136ms/step - loss: 0.0324 - accuracy: 0.9980 - val_loss: 3.0623 - val_accuracy: 0.9293
# Epoch 34/40
# 78/78 [==============================] - 11s 136ms/step - loss: 0.0747 - accuracy: 0.9964 - val_loss: 3.9600 - val_accuracy: 0.9068
# Epoch 35/40
# 78/78 [==============================] - 11s 137ms/step - loss: 0.0348 - accuracy: 0.9976 - val_loss: 3.5645 - val_accuracy: 0.9228
# Epoch 36/40
# 78/78 [==============================] - 11s 136ms/step - loss: 0.0043 - accuracy: 0.9992 - val_loss: 3.3741 - val_accuracy: 0.9277
# Epoch 37/40
# 78/78 [==============================] - 11s 136ms/step - loss: 1.7023e-08 - accuracy: 1.0000 - val_loss: 3.3785 - val_accuracy: 0.9277
# Epoch 38/40
# 78/78 [==============================] - 11s 136ms/step - loss: 1.6590e-08 - accuracy: 1.0000 - val_loss: 3.3785 - val_accuracy: 0.9277
# Epoch 39/40
# 78/78 [==============================] - 11s 136ms/step - loss: 1.6494e-08 - accuracy: 1.0000 - val_loss: 3.3785 - val_accuracy: 0.9277
# Epoch 40/40
# 78/78 [==============================] - 11s 136ms/step - loss: 1.5772e-08 - accuracy: 1.0000 - val_loss: 3.3786 - val_accuracy: 0.9277

# %%
plot_loss_curves(history)

# %%
model.evaluate(test_gen)
# Out:
# 3/3 [==============================] - 13s 7s/step - loss: 6.2198 - accuracy: 0.9114
# [6.219815254211426, 0.9113923907279968]

# %%
# y_pred = tf.math.round(model.predict(test_gen))
# y_true = []
# for images, labels in test_gen.unbatch():
#   y_true.append(labels.numpy())

# %%
# accuracy_score(y_true, y_pred)

# %%
# print(classification_report(y_true, y_pred, target_names=train_data.class_names))

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_auc_score
from keras.utils.np_utils import to_categorical
import numpy as np
print("==============TEST RESULTS============")

num_classes = len(train_gen.class_indices)
test_labels = test_gen.classes
test_labels = to_categorical(test_labels, num_classes=num_classes)
y_true = [i.argmax() for i in test_labels]

predictions = model.predict(test_gen, verbose=1)
yPredictions = np.argmax(predictions, axis=1)
true_classes = test_gen.classes
confusion_mtx = confusion_matrix(true_classes, yPredictions) 
y_pred_probabilities=yPredictions
classnames=[]
for classname in test_gen.class_indices:
    classnames.append(classname)

target_names = classnames
print(classification_report(true_classes, yPredictions, target_names=target_names))

# print('roc_auc_score = ' + str(roc_auc_score( true_classes, yPredictions)))
# Out:
# ==============TEST RESULTS============
# 3/3 [==============================] - 1s 116ms/step
#               precision    recall  f1-score   support
#
#   Chickenpox       0.83      0.91      0.87        11
#      Measles       0.77      1.00      0.87        10
#    Monkeypox       0.93      0.89      0.91        28
#       Normal       1.00      0.90      0.95        30
#
#     accuracy                           0.91        79
#    macro avg       0.88      0.93      0.90        79
# weighted avg       0.92      0.91      0.91        79

# %%
sns.heatmap(confusion_mtx.astype("int"), annot=True)

# %%
model.save('monkeypox_EfficientNetB3_with_Transferlearnig_on_Augmented_95.h5')
