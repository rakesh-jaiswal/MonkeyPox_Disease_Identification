# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import random
from tensorflow.keras import layers, Model
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install split-folders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import splitfolders

# Split with a ratio.
# To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.
splitfolders.ratio("/content/drive/MyDrive/Monkeypox Skin Image Dataset", output="test_train_val-original",
    seed=1337, ratio=(.8, .1, .1), group_prefix=None, move=False) # default values
# Out:
# Copying files: 770 files [00:20, 37.46 files/s]

# %%
train_dir = "/content/test_train_val-original/train"
val_dir = "/content/test_train_val-original/val"
test_dir = "/content/test_train_val-original/test"

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
                                                          # featurewise_center=True,
                                                          # featurewise_std_normalization=True,
                                                          # rotation_range=90,
                                                          # width_shift_range=0.2,
                                                          # height_shift_range=0.2,
                                                          # horizontal_flip=True,
                                                          # zoom_range=0.2,
                                                          )

# %%
train_gen = datagen.flow_from_directory(train_dir,
                                                 target_size = (224,224),
                                                 batch_size = 32,
                                        shuffle=True,
                                                 class_mode = 'categorical')
test_gen= datagen.flow_from_directory(test_dir,
                                            target_size = (224,224),
                                            batch_size = 32,
                                      shuffle=False,
                                            class_mode ='categorical')
val_gen = datagen.flow_from_directory(val_dir,
                                            target_size = (224,224),
                                            batch_size = 32,
                                      shuffle=True,
                                          class_mode = 'categorical')
# Out:
# Found 614 images belonging to 4 classes.
# Found 81 images belonging to 4 classes.
# Found 75 images belonging to 4 classes.

# %%
# IMG_SIZE = (224, 224)

# train_data = tf.keras.preprocessing.image_dataset_from_directory(directory=train_dir,
#                                                                  image_size=IMG_SIZE,
#                                                                  label_mode="categorical",
#                                                                  shuffle=True,
#                                                                  batch_size=32)


# test_data = tf.keras.preprocessing.image_dataset_from_directory(directory=test_dir,
#                                                                  image_size=IMG_SIZE,
#                                                                  label_mode="categorical",
#                                                                  batch_size=32,
#                                                                 shuffle=False)

# val_data = tf.keras.preprocessing.image_dataset_from_directory(directory=val_dir,
#                                                                  image_size=IMG_SIZE,
#                                                                  label_mode="categorical",
#                                                                  batch_size=32,
#                                                                 shuffle=True)

# %%
# Visualizing data
import os 
def visualize_random_images(dataset_type="train", label_type="Monkeypox"):
    
    sample = 9
    
    plt.figure(figsize=(15, 8))
    type_dir = train_dir if dataset_type=="train" else test_dir
    base_dir = os.path.join(type_dir, label_type)
    images = random.sample(os.listdir(base_dir), 9)
    
    for i, image in enumerate(images):
        plt.subplot(3, 3, i+1)
        img = plt.imread(os.path.join(base_dir, image))
        plt.imshow(img)

# %%
visualize_random_images("/content/test_train_val-original/test/Monkeypox/monkeypox107.png")

# %%
def plot_loss_curves(history):
  """
  Returns separate loss curves for training and validation metrics.
  Args:
    history: TensorFlow model History object (see: https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/History)
  """ 
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  # Plot accuracy
  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

# %%
base_model = tf.keras.applications.MobileNetV2(include_top=False)
base_model.trainable = False

for layer in base_model.layers[:-5]:
  layer.trainable = False

inputs = layers.Input(shape=(224, 224, 3), name="input_layer")
base_layer = base_model(inputs)

flat_layer = layers.Flatten()(base_layer)

outputs = layers.Dense(4, activation="softmax")(flat_layer)
model = Model(inputs, outputs)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# 9420800/9406464 [==============================] - 0s 0us/step

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001),
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = model.fit(train_gen,
                       epochs=40,
                       validation_data=val_gen)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/40
# 20/20 [==============================] - 19s 160ms/step - loss: 9.7948 - accuracy: 0.5309 - val_loss: 5.1062 - val_accuracy: 0.5733
# Epoch 2/40
# 20/20 [==============================] - 2s 96ms/step - loss: 2.5571 - accuracy: 0.7231 - val_loss: 1.8946 - val_accuracy: 0.7600
# Epoch 3/40
# 20/20 [==============================] - 2s 97ms/step - loss: 0.9170 - accuracy: 0.8274 - val_loss: 2.9060 - val_accuracy: 0.6267
# Epoch 4/40
# 20/20 [==============================] - 2s 97ms/step - loss: 0.4518 - accuracy: 0.8990 - val_loss: 1.6758 - val_accuracy: 0.7467
# Epoch 5/40
# 20/20 [==============================] - 2s 95ms/step - loss: 0.1257 - accuracy: 0.9625 - val_loss: 1.6417 - val_accuracy: 0.7467
# Epoch 6/40
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0695 - accuracy: 0.9788 - val_loss: 2.2075 - val_accuracy: 0.7600
# Epoch 7/40
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0194 - accuracy: 0.9902 - val_loss: 1.3757 - val_accuracy: 0.7333
# Epoch 8/40
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0159 - accuracy: 0.9902 - val_loss: 1.1876 - val_accuracy: 0.7867
# Epoch 9/40
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0074 - accuracy: 0.9984 - val_loss: 1.3396 - val_accuracy: 0.7467
# Epoch 10/40
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0089 - accuracy: 0.9984 - val_loss: 1.9617 - val_accuracy: 0.7333
# Epoch 11/40
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.2420 - val_accuracy: 0.7467
# Epoch 12/40
# 20/20 [==============================] - 2s 96ms/step - loss: 7.5643e-04 - accuracy: 1.0000 - val_loss: 1.3453 - val_accuracy: 0.7600
# Epoch 13/40
# 20/20 [==============================] - 2s 95ms/step - loss: 1.6304e-04 - accuracy: 1.0000 - val_loss: 1.4539 - val_accuracy: 0.7467
# Epoch 14/40
# 20/20 [==============================] - 2s 94ms/step - loss: 1.4783e-04 - accuracy: 1.0000 - val_loss: 1.4250 - val_accuracy: 0.7467
# Epoch 15/40
# 20/20 [==============================] - 2s 94ms/step - loss: 1.2910e-04 - accuracy: 1.0000 - val_loss: 1.4213 - val_accuracy: 0.7467
# Epoch 16/40
# 20/20 [==============================] - 2s 94ms/step - loss: 1.2080e-04 - accuracy: 1.0000 - val_loss: 1.4301 - val_accuracy: 0.7600
# 20/20 [==============================] - 2s 94ms/step - loss: 7.0808e-05 - accuracy: 1.0000 - val_loss: 1.4723 - val_accuracy: 0.7600
# Epoch 34/40
# 20/20 [==============================] - 2s 94ms/step - loss: 6.9218e-05 - accuracy: 1.0000 - val_loss: 1.4802 - val_accuracy: 0.7600
# Epoch 35/40
# 20/20 [==============================] - 2s 94ms/step - loss: 6.7803e-05 - accuracy: 1.0000 - val_loss: 1.4775 - val_accuracy: 0.7600
# Epoch 36/40
# 20/20 [==============================] - 2s 94ms/step - loss: 6.6248e-05 - accuracy: 1.0000 - val_loss: 1.4839 - val_accuracy: 0.7600
# Epoch 37/40
# 20/20 [==============================] - 2s 94ms/step - loss: 6.4970e-05 - accuracy: 1.0000 - val_loss: 1.4843 - val_accuracy: 0.7600
# Epoch 38/40
# 20/20 [==============================] - 2s 93ms/step - loss: 6.3503e-05 - accuracy: 1.0000 - val_loss: 1.4822 - val_accuracy: 0.7733
# Epoch 39/40
# 20/20 [==============================] - 2s 96ms/step - loss: 6.2286e-05 - accuracy: 1.0000 - val_loss: 1.4816 - val_accuracy: 0.7733
# Epoch 40/40
# 20/20 [==============================] - 2s 96ms/step - loss: 6.1124e-05 - accuracy: 1.0000 - val_loss: 1.4839 - val_accuracy: 0.7733

# %%
plot_loss_curves(history)

# %%
# model.evaluate(test_data)

# %%
# y_pred = tf.math.round(model.predict(test_gen))
# y_true = []
# for images, labels in test_gen.unbatch():
#   y_true.append(labels.numpy())

# %%
# accuracy_score(y_true, y_pred)

# %%
# print(classification_report(y_true, y_pred, target_names=train_data.class_names))

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_auc_score
from keras.utils.np_utils import to_categorical
import numpy as np
print("==============TEST RESULTS============")

num_classes = len(train_gen.class_indices)
test_labels = test_gen.classes
test_labels = to_categorical(test_labels, num_classes=num_classes)
y_true = [i.argmax() for i in test_labels]

predictions = model.predict(test_gen, verbose=1)
yPredictions = np.argmax(predictions, axis=1)
true_classes = test_gen.classes
confusion_mtx = confusion_matrix(true_classes, yPredictions) 
y_pred_probabilities=yPredictions
classnames=[]
for classname in test_gen.class_indices:
    classnames.append(classname)

target_names = classnames
print(classification_report(true_classes, yPredictions, target_names=target_names))

# print('roc_auc_score = ' + str(roc_auc_score( true_classes, yPredictions)))
# Out:
# ==============TEST RESULTS============
# 3/3 [==============================] - 1s 229ms/step
#               precision    recall  f1-score   support
#
#   Chickenpox       0.40      0.17      0.24        12
#      Measles       1.00      0.50      0.67        10
#    Monkeypox       0.75      0.93      0.83        29
#       Normal       0.77      0.90      0.83        30
#
#     accuracy                           0.75        81
#    macro avg       0.73      0.62      0.64        81
# weighted avg       0.74      0.75      0.72        81

# %%
sns.heatmap(confusion_mtx.astype("int"), annot=True)

# %%
model.save('monkeypox_detection_on_original85.h5')
